# %%
import time

import numpy as np

N = 1000000
w = np.random.rand(N)
x = np.random.rand(N)
b = 4.5

# -------------------------------------------------------------

f_loop = 0.0
start_time = time.time()

for j in range(N):
    f_loop += w[j] * x[j]
f_loop += b

end_time = time.time()
loop_time = (end_time - start_time) * 1000  

# -------------------------------------------------------------

start_time = time.time()

f_vec = np.dot(w, x) + b  

end_time = time.time()
vec_time = (end_time - start_time) * 1000  

# -------------------------------------------------------------

print(f"For Loop Time     : {loop_time:.2f} ms")
print(f"Vectorization Time: {vec_time:.2f} ms")
print(f"Vectorization Faster By [{loop_time / vec_time:.1f}] Time!")
# Out:
# For Loop Time     : 459.82 ms
# Vectorization Time: 1.40 ms
# Vectorization Faster By [327.4] Time!
