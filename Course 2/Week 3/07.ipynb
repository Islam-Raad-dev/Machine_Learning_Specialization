# %%
import torch
import torch.nn as nn
from torch.utils.data import DataLoader, TensorDataset

x_train = torch.tensor(x_train_raw, dtype=torch.float32) / 255.0
y_train = torch.tensor(y_train_raw, dtype=torch.long)

train_loader = DataLoader(TensorDataset(x_train, y_train), batch_size=32, shuffle=True)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

class NeuralNetwork(nn.Module):
    def __init__(self):
        super().__init__()
        self.flatten = nn.Flatten()
        self.layer1 = nn.Linear(28*28, 128)
        self.relu = nn.ReLU()
        self.dropout = nn.Dropout(0.2)
        self.layer2 = nn.Linear(128, 10)

    def forward(self, x):
        return self.layer2(self.dropout(self.relu(self.layer1(self.flatten(x)))))

model = NeuralNetwork().to(device)
loss_fn = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters())

for epoch in range(5):
    for xb, yb in train_loader:
        xb, yb = xb.to(device), yb.to(device)
        optimizer.zero_grad()
        loss = loss_fn(model(xb), yb)
        loss.backward()
        optimizer.step()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_1568/281704166.py in <cell line: 0>()
#       3 from torch.utils.data import DataLoader, TensorDataset
#       4
# ----> 5 x_train = torch.tensor(x_train_raw, dtype=torch.float32) / 255.0
#       6 y_train = torch.tensor(y_train_raw, dtype=torch.long)
#       7
#
# NameError: name 'x_train_raw' is not defined
