# %%
from tensorflow import keras
from tensorflow.keras import layers

(x_train, y_train), (x_test, y_test) = keras.datasets.mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 2s 0us/step

# %%
x_train = x_train.astype("float32") / 255.0
x_test = x_test.astype("float32") / 255.0

# %%
model = keras.Sequential([
    layers.Input(shape=(28, 28)),
    layers.Flatten(),
    layers.Dense(128, activation="relu"),
    layers.Dropout(0.2),
    layers.Dense(10, activation="softmax"),
])

# %%
model.compile(
    optimizer="adam",
    loss="sparse_categorical_crossentropy",
    metrics=["accuracy"],
)

# %%
model.fit(x_train, y_train, epochs=5, batch_size=32, validation_split=0.1)
# Out:
# Epoch 1/5
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9086 - loss: 0.3130 - val_accuracy: 0.9643 - val_loss: 0.1281
# Epoch 2/5
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.9557 - loss: 0.1499 - val_accuracy: 0.9653 - val_loss: 0.1100
# Epoch 3/5
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - accuracy: 0.9650 - loss: 0.1151 - val_accuracy: 0.9773 - val_loss: 0.0760
# Epoch 4/5
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9714 - loss: 0.0926 - val_accuracy: 0.9787 - val_loss: 0.0713
# Epoch 5/5
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9751 - loss: 0.0807 - val_accuracy: 0.9805 - val_loss: 0.0664

# %%
test_loss, test_acc = model.evaluate(x_test, y_test)
print(f"دقة الاختبار: {test_acc:.2%}")   # 97.49% 

model.save("mnist_classifier.keras")
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9773 - loss: 0.0745
# دقة الاختبار: 97.73%
